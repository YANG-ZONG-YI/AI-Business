# %% [markdown]
# <a href="https://colab.research.google.com/github/YANG-ZONG-YI/AI-Business/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
if a > 5:
    if a == 6:
        pass
    else:
        pass
else:
    pass
# Out:
# 3

# %%
print(a+2)
# Out:
# 5

# %% [markdown]
# - latex math
#     - 特殊符號:\
#     - () -> {}
#     - $ area = \frac{4}{3+x} \pi R^3 $
